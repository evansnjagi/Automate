# %% [markdown]
# # Chapter 6: Lists
# ---

# %% [markdown]
# A list is a collection of items.

# %%
petNames = [] # Created an empty list

# Adding new pet petNames
petNames.append("cat")
petNames.append("lion")
petNames.append("lizzard")

print(petNames)
# Out:
# ['cat', 'lion', 'lizzard']

# %%
# Empty list instantiation
colors = []
# Get user's input
color = input("Enter you favouring colors (3): ")

# Appending user's input to the created empty list
colors.append(color)

# Print the results
print(f"Your favourite colors are: {colors}")
# Out:
# Your favourite colors are: ['red']

# %%
# collections
colors = []

for i in range(3):
    color = input(f"Enter your favourite color #{1 + i}: ")
    colors.append(color)

# Priting the results
print(f"Your favourite colors are: {colors}")
# Out:
# Your favourite colors are: ['blue', 'green', 'red']

# %% [markdown]
# Write a program that asks the user for 5 numbers and print only the even numbers

# %%
numbers = []
for i in range(5):
    number = input(f"Enter number #{i + 1}: ")

    # Check if the input number is an even number
    try:
        if not (int(number) % 2):
            numbers.append(number)
    except Exception as err:
        print(f"Invalid. This error has occured: {err}")

# Printing the results (even numbers only)
print(f"Even numbers are: {numbers}")
# Out:
# Even numbers are: ['2', '4']

# %% [markdown]
# `.append` Adds the item to the existing list, therefore, it is memory efficient when you only want to add one item.

# %%
print(numbers.insert(0,6))
# Out:
# None

# %%
print(numbers)
# Out:
# [6, '2', '4']

# %%
numbers = []
for i in range(5):
    number = input(f"Enter number #: {i + 1}: ")

    # Validate the input number
    while True:
        try:
            number = int(number)
            
            # Appending the number to the list
            numbers.append(number)

            # Exciting loop if valid
            break
        except Exception as err:
            print("Invalid number. Try again!")

print(f"Your numbers are: {numbers}")

# for i in numbers[:]:
#     if i % 2:
#         numbers.remove(i)

# We can as well use a list comprehension
numbers = [number for number in numbers[:] if number % 2 == 0]

# Printing the new list
print(f"Even number list: {numbers}")
# Out:
# Your numbers are: [1, 2, 3, 4, 5]
# Even number list: [2, 4]

# %%
# Inserting odd numbers in from of a list
numbers = []

for i in range(5):
    while True:
        number = input(f"Enter number #{i + 1}: ")
        try:
            number = int(number)
            numbers.append(number)

            break
        except Exception as err:
            print(err)
for i in numbers[:]:
    if i % 2:
        # Removing and inserting the odd number
        numbers.remove(i)
        numbers.insert(0, i)

print(f"New list: {numbers}")

# %%
# Creating a list of 6 numbers from input
numbers = [int(input(f"Enter number #{i + 1}: ")) for i in range(6)]

# printing the first and last element
print(f"The first and last : {numbers[0], numbers[-1]}")

# The middle four elements
totalNumbers = len(numbers)
if totalNumbers < 4:
    print("Fewer than four elements")

elif totalNumbers == 4:
    print(f"The middle 4 elements: {numbers}")
else:
    if totalNumbers % 2 == 0:
        midNumber = totalNumbers // 2
        start = midNumber - 2
        end = midNumber + 2
        print(f"The middle 4 elements: {numbers[start: end]}")
    else:
        print("You can not get the middle four elements!")
# Reversed list
print(f"Reversed list: {numbers[::-1]}")

# Getting every second number
print(f"Every second number: {numbers[::2]}")
# Out:
# The first and last : (1, 6)
# The middle 4 elements: [2, 3, 4, 5]
# Reversed list: [6, 5, 4, 3, 2, 1]
# Every second number: [1, 3, 5]

# %%
# Import module
import random 

# Working with random choice
list = ["one", "two", "thee", "four"]

choice = random.choice(list)
print(choice)
# Out:
# one

# %%
# Adding five to make the list complete
list.append("five")

# %%
# Shuffling the list of  5 numbers
random.shuffle(list)

print(list)
# Out:
# ['thee', 'one', 'five', 'four', 'two']

# %% [markdown]
# ## Sorting

# %%
# make a list of students
students = ["James", "Ann", "Christopher", "Bob", "Elizabeth"]
studentsCopy = students[:]

# Sort them alphabetically
studentsCopy.sort()
print(f"Sorted students list: {studentsCopy}")

# Sort the students list by their lengths
studentsCopy.sort(key = len)
print(f"Sorted by length: {studentsCopy}")

# Sort by last letter
studentsCopy.sort(key = lambda student: student[-1])
print(f"Sorted by last digit: {studentsCopy}")
# Out:
# Sorted students list: ['Ann', 'Bob', 'Christopher', 'Elizabeth', 'James']
# Sorted by length: ['Ann', 'Bob', 'James', 'Elizabeth', 'Christopher']
# Sorted by last digit: ['Bob', 'Elizabeth', 'Ann', 'Christopher', 'James']

# %%
# Stable sorting
studentsSorted = sorted(students, key = lambda student: (len(student), student))

print(f"Original list: {students}")
print(f"Sorted list by length and by alphabet: {studentsSorted}")
# Out:
# Original list: ['James', 'Ann', 'Christopher', 'Bob', 'Elizabeth']
# Sorted list by length and by alphabet: ['Ann', 'Bob', 'James', 'Elizabeth', 'Christopher']
